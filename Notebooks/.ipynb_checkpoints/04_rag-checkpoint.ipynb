# %% [markdown]
# ### Imports

# %%
from langchain_community.document_loaders import PyPDFLoader, TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_ollama import OllamaEmbeddings, ChatOllama
from langchain_chroma import Chroma

# %% [markdown]
# ### Load PDF Files

# %%
pdf_files = [
    "../data/PDF/oecd_consumer_protection_ecommerce.pdf",
    "../data/PDF/oecd_online_marketplaces_consumer_protection.pdf"
]

pdf_documents = []

for file in pdf_files:
    loader = PyPDFLoader(file)
    pdf_documents.extend(loader.load())

print(f"Loaded {len(pdf_documents)} PDF pages")

# %% [markdown]
# ### Load Text Files

# %%
text_files = [
    "../data/Text/General Terms.txt",
    "../data/Text/Privacy Policy.txt",
    "../data/Text/Shipping Terms.txt",
    "../data/Text/Ecommerce Terms.txt"
]

text_documents = []

for file in text_files:
    loader = TextLoader(file, encoding="utf-8")
    text_documents.extend(loader.load())

print(f"Loaded {len(text_documents)} text documents")

# %% [markdown]
# ### Combine Documents

# %%
documents = pdf_documents + text_documents

print(f"Total documents loaded: {len(documents)}")

# %% [markdown]
# ### Split Documents

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200
)

chunks = text_splitter.split_documents(documents)

print(f"Total chunks: {len(chunks)}")

# %% [markdown]
# ### Embedding Model

# %%
embeddings = OllamaEmbeddings(
    model="nomic-embed-text"
)

# %% [markdown]
# ### Vector DB

# %%
vectorstore = Chroma.from_documents(
    documents=chunks,
    embedding=embeddings,
    persist_directory="../chroma_db"
)

# %%
retriever = vectorstore.as_retriever(
    search_kwargs={"k": 4}
)

# %%
query = "What does Olist's privacy policy say about personal data?"

retrieved_docs = retriever.invoke(query)

print(f"Retrieved {len(retrieved_docs)} documents\n")

for i, doc in enumerate(retrieved_docs, 1):
    print(f"--- Document {i} ---")
    print(doc.page_content[:1000])
    print()

# %% [markdown]
# ### LLM

# %%
llm = ChatOllama(
    model="qwen3:4b",
    temperature=0
)

# %% [markdown]
# ### Rag

# %%
def rag_answer(question: str) -> str:
    retrieved_docs = retriever.invoke(question)

    context = "\n\n".join(
        doc.page_content for doc in retrieved_docs
    )

    prompt = f"""
Answer the question using only the context below.

Context:
{context}

Question:
{question}

If the answer is not present in the context, say that the information is not available in the provided documents.
"""

    response = llm.invoke(prompt)

    return response.content

# %%
answer = rag_answer(
    "What does Olist's privacy policy say about personal data?"
)

print(answer)

# %%
answer2 = rag_answer(
    "What are Olist's shipping terms?"
)

print(answer2)
